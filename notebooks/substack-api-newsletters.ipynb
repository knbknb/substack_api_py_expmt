# %%
#%pip install substack-api

#Collecting beautifulsoup4
#Collecting requests
#Collecting soupsieve
#Collecting charset-analyzer
#Collecting idna
#Collecting urllib3
#Collecting certifi

# %% [markdown]
# # Usage of substack_api module

# %%
from substack_api import newsletter
# from substack_api import user
from pprint import pprint
from IPython.display import display, HTML

# %%
categories_2024 = [
    ("Knowledge, Art, Literature", ["Art & Illustration", "Comics", "Culture", "Design", "Education", "Faith & Spirituality", "Fashion & Beauty", "Fiction", "History", "Literature", "Music", "Philosophy"]),
    ("News+Politics", ["Business", "Finance", "Health Politics", "International", "News", "U.S. Politics", "World Politics"]),
    ("Science+Technology", ["Climate & Environment", "Crypto", "Health & Wellness", "Science", "Technology"]),
    ("Leisure", ["Food & Drink", "Humor", "Parenting", "Podcasts", "Sports", "Travel"])
]

# %% [markdown]
# ##### List all categories on Substack:

# %%
# returns a list of tupley (name, count)
categories = newsletter.list_all_categories()
categories.sort(key=lambda x: x[0])
# list categories, grouped by the 2024 categories
display(HTML('<h3>Categories (2024) and their category id</h3>'))
for cat_2024 in categories_2024:
    display(HTML(f'<h4>{cat_2024[0]}</h4>'))
    for cat in categories:
        if cat[0] in cat_2024[1]:
            #display(HTML(f'<b>{cat[0]}</b>: {cat[1]}'))
            print(f"{cat[0]}: {cat[1]}")
# Out:
# <h3>Categories (2024) and their category id</h3>
# <h4>Knowledge, Art, Literature</h4>
# Art & Illustration: 15417
# Comics: 387
# Culture: 96
# Design: 61
# Education: 34
# Faith & Spirituality: 223
# Fashion & Beauty: 49715
# Fiction: 284
# History: 18
# Literature: 339
# Music: 11
# Philosophy: 114
# <h4>News+Politics</h4>
# Business: 62
# Finance: 153
# Health Politics: 76741
# International: 51282
# News: 103
# U.S. Politics: 76739
# World Politics: 76740
# <h4>Science+Technology</h4>
# Climate & Environment: 15414
# Crypto: 118
# Health & Wellness: 355
# Science: 134
# Technology: 4
# <h4>Leisure</h4>
# Food & Drink: 13645
# Humor: 49692
# Podcasts: podcast
# Sports: 94
# Travel: 109

# %% [markdown]
# ##### Get metadata for the first 2 pages of Technology newsletters:
#
# - Category 4 is Technology
# - Category 118 is Crypto

# %%
cat_num = 118
newsletters_metadata = newsletter.get_newsletters_in_category(cat_num, start_page=0, end_page=2)
# Out:
# page 1 done
# page 2 done

# %%
# print the metadata of the first newsletter
pprint(newsletters_metadata[0].keys())

# print hero texts of all newsletters
for newsletter_metadata in newsletters_metadata:
    print(newsletter_metadata["hero_text"])
# Out:
# dict_keys(['apple_pay_disabled', 'apex_domain', 'author_id', 'byline_images_enabled', 'bylines_enabled', 'chartable_token', 'community_enabled', 'copyright', 'cover_photo_url', 'created_at', 'custom_domain_optional', 'custom_domain', 'custom_publication_theme_id', 'default_comment_sort', 'default_coupon', 'default_group_coupon', 'default_show_guest_bios', 'email_banner_url', 'email_from_name', 'email_from', 'embed_tracking_disabled', 'explicit', 'expose_paywall_content_to_search_engines', 'fb_pixel_id', 'fb_site_verification_token', 'flagged_as_spam', 'founding_subscription_benefits', 'free_subscription_benefits', 'ga_pixel_id', 'google_site_verification_token', 'google_tag_manager_token', 'hero_image', 'hero_text', 'hide_intro_subtitle', 'hide_intro_title', 'hide_podcast_feed_link', 'homepage_type', 'id', 'image_thumbnails_always_enabled', 'invite_only', 'language', 'logo_url_wide', 'logo_url', 'minimum_group_size', 'moderation_enabled', 'name', 'paid_subscription_benefits', 'parsely_pixel_id', 'payments_state', 'paywall_free_trial_enabled', 'podcast_art_url', 'paid_podcast_episode_art_url', 'podcast_byline', 'podcast_description', 'podcast_enabled', 'podcast_feed_url', 'podcast_title', 'post_preview_limit', 'require_clickthrough', 'rss_feed_url', 'rss_website_url', 'show_pub_podcast_tab', 'show_recs_on_homepage', 'subdomain', 'subscriber_invites', 'support_email', 'theme_var_background_pop', 'theme_var_color_links', 'theme_var_cover_bg_color', 'trial_end_override', 'twitter_pixel_id', 'type', 'post_reaction_faces_enabled', 'is_personal_mode', 'plans', 'stripe_user_id', 'stripe_country', 'stripe_publishable_key', 'automatic_tax_enabled', 'author_name', 'author_handle', 'author_photo_url', 'author_bio', 'twitter_screen_name', 'twitter_share_on_publish_opt_in', 'has_custom_tos', 'has_custom_privacy', 'theme', 'threads_v2_settings', 'default_group_coupon_percent_off', 'pause_return_date', 'has_posts', 'has_recommendations', 'first_post_date', 'has_podcast', 'has_free_podcast', 'has_subscriber_only_podcast', 'has_community_content', 'twitter_permissions', 'rankingDetail', 'rankingDetailFreeIncluded', 'rankingDetailOrderOfMagnitude', 'rankingDetailFreeIncludedOrderOfMagnitude', 'rankingDetailFreeSubscriberCount', 'rankingDetailByLanguage', 'freeSubscriberCount', 'freeSubscriberCountOrderOfMagnitude', 'author_bestseller_tier', 'disable_monthly_subscriptions', 'disable_annual_subscriptions', 'hide_post_restacks', 'notes_feed_enabled', 'last_chat_post_at', 'no_follow', 'paywall_chat', 'sections', 'multipub_migration', 'navigationBarItems', 'contributors', 'threads_v2_enabled', 'viralGiftsConfig', 'tier', 'no_index', 'can_set_google_site_verification', 'can_have_sitemap', 'founding_plan_name_english', 'draft_plans', 'base_url', 'hostname', 'is_on_substack', 'spotify_podcast_settings', 'podcastPalette', 'pageThemes', 'live_subscriber_counts'])
# Pomp's daily newsletter analyzing the business, finance, and technology industries. Join 260,000 subscribers by signing up below.
# Your daily crypto fill, from the deep, dark burrows of the blockchain. Handpicked and crafted with love by human bots 🤟
#
# We help connect blockchains, crypto projects and protocols with their ecosystems. Diving into top metrics, progress, product releases, team insights and more. All in one place.
# The #1 Paid Crypto Substack. No non-sense writing style covering: 1) Crypto, 2) Tech Stocks, 3) WiFi money and 4) Real Estate. Written by anon Ex-Wall St and Tech Individuals. SPONSOR FREE.
# The top weekly newsletter for institutional crypto. All things DeFi, blockchain, Web 3.0, crypto funds, and the future of money. With analysis of the macro trends and technological innovation as we build an open financial system for the world.
# Rejoins +74.000 membres pour apprendre gratuitement à investir & trader grâce aux analyses de marchés envoyées chaque lundi par e-mail. Après ton inscription, tu recevras une formation gratuite de 36 cours sur le trading et l’investissement.
# With a focus on Bitcoin, macro, DeFi, AI and web3, our goal is to provide an all-encompassing overview of the crypto asset market and the technological trends shaping it.
# Free institutional-grade market intelligence from Blockware Solutions, written by Head Analyst Mitch Askew (@MitchellHODL) and Macro Analyst Blake Davis (@BlakeDavis50).
# your go-to guide on the next internet from the team at a16z crypto
# Building the Largest Modular Data Layer for Gaming & AI.
# The ABCs for adults about earning income and controlling risk in Blockchain
#
# Reçois la newsletter de Julien Roman pour investir en cryptomonnaie en 2025 plus sereinement.
# A bite-sized daily newsletter packed with crypto news—everything you need to know in minutes. From the world’s fastest-growing crypto YouTube channel, bringing you credible insights daily. By reading, you agree to our disclaimer.
# Join 27,000+ others looking for the top alternative to mainstream news.  Arb Letter brings you simple and actionable commentary on geopolitics, financial markets, crypto, and life.  ARB Letter is read across 50 US states and 167 countries.
# Le Web3 en 2 minutes chaque jour, gratuitement 🚀 (+240 000 lectures par mois)
# Your Gateway to Blockchain Research, Comprehensive Audits, and In-Depth Investment Analysis.
#
# As principais notícias, análises e tendências do do mercado cripto e da Web3, todos os dias, no seu e-mail. Não perca tempo e se inscreva agora!
# Bitcoin Magazine Pro publishes in-depth research on bitcoin & traditional financial markets. Our team of experts covers macroeconomics, on-chain data, derivatives markets, the bitcoin mining industry & more to unpack the most important market trends.
# Turn your questions into answers.
#
# Entity-powered Web3 analytics to make better decisions faster.
# From Shakespeare to sharding : English media's 2-minute takes on Web3.
# The latest news about NFTs by the Lazy.com team
# The newsletter about crypto, DeFi, and other speculative markets.
# Bi-weekly updates on macro crypto market view, altcoin market assessment and targets, and exit/reinvestment strategies. Exclusive access to live Bitcoin impulse top/correction low indicators.
# Join the Crypto.com community with over 80 million users. Become smarter on crypto with Crypto.com Research's weekly updates on the market, DeFi, Layer-1 & 2, NFT, and Gaming. It only takes 2 mins or less to read and it’s free!
# A weekly newsletter by Paul Veradittakit, crypto investor at Pantera Capital
# The Substack of Arthur Hayes, Chief Investment Officer of Maelstrom, co-founder and former CEO of BitMEX, a faithful disciple of the one true god Satoshi, and all around mother fucker.
# Bitcoin and global macro research firm.
# Daily defi + macro news, data, updates, and alerts in a quick easy to read format!
# Your no-hype resource for all things crypto
# Crypto, Hebdo, Let's Go!
# The best new blockchain and cryptocurrency jobs
# Subscribe to the Flowverse weekly newsletter to receive your free Flow Surfer NFT
# Crypto trends, onchain analysis, and DeFi. Learn how to research crypto. Sign up for a free guide to on-chain analysis.
# Long-Term Bitcoin On-Chain, Chart, Psychology and Model Analysis. Proven Effective. Profit Focused.
# Stories with depth, insight & data covering all things Web3.
# For builders. By builders.
# 說人話的區塊鏈圖文，每週 3 篇原創內容直送信箱
# Meet your new Bitcoin Personal Trainer. We provide straightforward market analysis, in-depth educational content and data-driven insights to help you see through the noise and respond with confidence.
# Finansal özgürlük için haftada 1 dakikasını ayıran 20.000+ kişiye ÜCRETSİZ şimdi katıl!
# Omnichain Perpetuals DEX. Trade any way, anywhere.
# Sailing the seven c’s of cryptocurrency. Navigating the world and bringing you all the educational treasures found. Aggregating alpha, touching in on trends, and bringing it all straight to you.
# Crypto market insights
# Crypto data for the decentralized economy
# Fique atualizado sobre as últimas tendências em Bitcoin, Criptomoedas, DeFi, NFT, Web 3.0, Blockchain e Layer 2.
# Bitcoin on-chain & cycle analysis.
# 暗号通貨/ブロックチェーンに関する海外情報を、毎週月曜日6:30amに発信する0円メルマガです☕2017年に開始し、おかげさまで好評いただき続けることができています🎊
# 暗号通貨/ブロックチェーンに興味がある人は是非読んでください。
# One curated piece of Bitcoin content each day. Only the highest quality articles, podcasts, and videos make the cut.
# Seu jornal diário de cripto. Direto ao ponto 📰
# Tous les jeudis, un tour d’horizon des marchés cryptos, des analyses et des tutos pour les utilisateurs débutants ou avancés.
#
# Exclusive crypto analysis and weekly DeFi updates to stay ahead of the curve.

# %%
#newsletter_id = "platformer"
newsletter_id = "arnicas" # must be subdomain of substack.com
display(HTML(f'<h3>Get post metadata for the most recent 30 posts from a newsletter: <code>{newsletter_id}</code></h3>'))
# Out:
# <h3>Get post metadata for the most recent 30 posts from a newsletter: <code>arnicas</code></h3>

# %%
newsletter.get_newsletter_post_metadata(newsletter_id, start_offset=0, end_offset=30)
# Out:
# [{'id': 153061591,
#   'editor_v2': False,
#   'publication_id': 626449,
#   'title': 'TITAA #61.5: Narrative Time Is Hard',
#   'social_title': None,
#   'search_engine_title': None,
#   'search_engine_description': None,
#   'type': 'newsletter',
#   'slug': 'titaa-615-narrative-time-is-hard',
#   'post_date': '2024-12-16T14:36:05.394Z',
#   'audience': 'only_paid',
#   'podcast_duration': None,
#   'video_upload_id': None,
#   'podcast_upload_id': None,
#   'write_comment_permissions': 'only_paid',
#   'should_send_free_preview': False,
#   'free_unlock_required': False,
#   'default_comment_sort': None,
#   'canonical_url': 'https://arnicas.substack.com/p/titaa-615-narrative-time-is-hard',
#   'section_id': None,
#   'top_exclusions': [],
#   'pins': [],
#   'is_section_pinned': False,
#   'section_slug': None,
#   'section_name': None,
#   'reactions': {'❤': 4},
#   'restacked_post_id': None,
#   'restacked_pub_name': None,
#   'restacked_pub_logo_url': None,
#   'subtitle': 'Video Gen - Dysentery - 3D Worlds - Gemini 2 - Houska Castle - Story Events',
#   'cover_image': 'https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fc5fb3172-b714-4367-a11a-c69222a6a39b_400x628.jpeg',
#   'cover_image_is_square': False,
#   'cover_image_is_explicit': False,
#   'podcast_url': None,
#   'videoUpload': None,
#   'podcastFields': {'post_id': 153061591,
#    'podcast_episode_number': None,
#    'podcast_season_number': None,
#    'podcast_episode_type': None,
#    'should_syndicate_to_other_feed': None,
#    'syndicate_to_section_id': None,
#    'hide_from_feed': False,
#    'free_podcast_url': None,
#    'free_podcast_duration': None},
#   'podcast_preview_upload_id': None,
#   'podcastUpload': None,
#   'podcastPreviewUpload': None,
#   'voiceover_upload_id': None,
#   'voiceoverUpload': None,
#   'has_voiceover': False,
#   'description': 'Video Gen - Dysentery - 3D Worlds - Gemini 2 - Houska Castle - Story Events',
#   'body_json': None,
#   'body_html': None,
#   'truncated_body_text': 'TOC (links on the web page):',
#   'wordcount': 4748,
#   'postTags': [{'id': '0127fbd4-080d-4021-ba50-8752dd4c53a1',
#     'publication_id': 626449,
#     'name': 'games',
#     'slug': 'games',
#     'hidden': False},
#    {'id': '5aba9d33-3a75-4411-beb6-ef659324c107',
#     'publication_id': 626449,
#     'name': 'folklore',
#     'slug': 'folklore',
#     'hidden': False},
#    {'id': '5c33f416-9046-4ced-91db-0307fa8dbfa8',
#     'publication_id': 626449,
#     'name': 'art',
#     'slug': 'art',
#     'hidden': False},
#    {'id': '954d87d3-23f1-4c50-b727-c9a40116e821',
#     'publication_id': 626449,
#     'name': 'ai',
#     'slug': 'ai',
#     'hidden': False},
#    {'id': '9bf1ab09-723d-4e3e-93ab-ef08b81f5a93',
#     'publication_id': 626449,
#     'name': 'video',
#     'slug': 'video',
#     'hidden': False},
#    {'id': 'bbdc0e28-78eb-476c-9e10-445c9c4b83cd',
#     'publication_id': 626449,
#     'name': 'nlp',
#     'slug': 'nlp',
#     'hidden': False},
#    {'id': 'ca5e0318-39d9-4275-a792-6a2c6f87bda9',
#     'publication_id': 626449,
#     'name': 'esoteric',
#     'slug': 'esoteric',
#     'hidden': False}],
#   'teaser_post_eligible': True,
#   'postCountryBlocks': [],
#   'coverImagePalette': {'Vibrant': {'rgb': [167.82051282051285,
#      154.74358974358975,
#      87.17948717948715],
#     'population': 0},
#    'DarkVibrant': {'rgb': [87.26666666666668,
#      80.46666666666667,
#      45.33333333333333],
#     'population': 0},
#    'LightVibrant': {'rgb': [209.66666666666669,
#      202.86666666666667,
#      167.73333333333332],
#     'population': 0},
#    'Muted': {'rgb': [132, 140, 114], 'population': 128},
#    'DarkMuted': {'rgb': [79, 82, 68], 'population': 316},
#    'LightMuted': {'rgb': [215, 209, 178], 'population': 318}},
#   'publishedBylines': [{'id': 1346842,
#     'name': 'Lynn Cherny',
#     'handle': 'arnicas',
#     'previous_name': None,
#     'photo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/ace812d6-e878-4ba0-af77-efeacd499379_450x512.jpeg',
#     'bio': 'AI for creativity & story, games; science fiction, TV, esoterica & weirdness. Twice-a-month newsletter on Things I Think Are Awesome: https://t.co/lgcNFxxTqj',
#     'profile_set_up_at': '2021-12-23T10:37:52.777Z',
#     'publicationUsers': [{'id': 559170,
#       'user_id': 1346842,
#       'publication_id': 626449,
#       'role': 'admin',
#       'public': True,
#       'is_primary': False,
#       'publication': {'id': 626449,
#        'name': 'Things I Think Are Awesome',
#        'subdomain': 'arnicas',
#        'custom_domain': None,
#        'custom_domain_optional': False,
#        'hero_text': 'Twice a month recs on creative AI, games and narrative tools, fun NLP and data science, generative art and text, SF/fantasy books & tv, poetry, oddities & folklore.',
#        'logo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/2646b087-18d7-4a3f-aced-d4f19b93406b_1024x1024.png',
#        'author_id': 1346842,
#        'theme_var_background_pop': '#B599F1',
#        'created_at': '2021-12-21T14:42:52.852Z',
#        'rss_website_url': None,
#        'email_from_name': 'Things I Think Are Awesome',
#        'copyright': 'Lynn Cherny',
#        'founding_plan_name': 'Founding Member',
#        'community_enabled': True,
#        'invite_only': False,
#        'payments_state': 'enabled',
#        'language': None,
#        'explicit': False,
#        'is_personal_mode': False}}],
#     'twitter_screen_name': 'arnicas',
#     'is_guest': False,
#     'bestseller_tier': 100}],
#   'reaction': None,
#   'reaction_count': 4,
#   'comment_count': 4,
#   'child_comment_count': 2,
#   'audio_items': [{'post_id': 153061591,
#     'voice_id': 'en-US-OnyxTurboMultilingualNeural',
#     'audio_url': None,
#     'type': 'tts',
#     'status': 'paywalled'}],
#   'is_geoblocked': False,
#   'hidden': True,
#   'hasCashtag': False},
#  {'id': 152321552,
#   'editor_v2': False,
#   'publication_id': 626449,
#   'title': 'TITAA #61: Surrealism, Alice & the Occult',
#   'social_title': None,
#   'search_engine_title': None,
#   'search_engine_description': None,
#   'type': 'newsletter',
#   'slug': 'titaa-61-surrealism-alice-and-the',
#   'post_date': '2024-11-30T17:14:50.663Z',
#   'audience': 'everyone',
#   'podcast_duration': None,
#   'video_upload_id': None,
#   'podcast_upload_id': None,
#   'write_comment_permissions': 'everyone',
#   'should_send_free_preview': False,
#   'free_unlock_required': False,
#   'default_comment_sort': None,
#   'canonical_url': 'https://arnicas.substack.com/p/titaa-61-surrealism-alice-and-the',
#   'section_id': None,
#   'top_exclusions': [],
#   'pins': [],
#   'is_section_pinned': False,
#   'section_slug': None,
#   'section_name': None,
#   'reactions': {'❤': 7},
#   'restacked_post_id': None,
#   'restacked_pub_name': None,
#   'restacked_pub_logo_url': None,
#   'subtitle': 'Exhibition - Video Gen - Transparent Ones - Unloved Poets - Firehose Vis',
#   'cover_image': 'https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2F4088d473-1efb-4b4b-87c5-e0c4fe9a1c7f_900x593.jpeg',
#   'cover_image_is_square': False,
#   'cover_image_is_explicit': False,
#   'podcast_url': '',
#   'videoUpload': None,
#   'podcastFields': {'post_id': 152321552,
#    'podcast_episode_number': None,
#    'podcast_season_number': None,
#    'podcast_episode_type': None,
#    'should_syndicate_to_other_feed': None,
#    'syndicate_to_section_id': None,
#    'hide_from_feed': False,
#    'free_podcast_url': None,
#    'free_podcast_duration': None},
#   'podcast_preview_upload_id': None,
#   'podcastUpload': None,
#   'podcastPreviewUpload': None,
#   'voiceover_upload_id': None,
#   'voiceoverUpload': None,
#   'has_voiceover': False,
#   'description': 'Exhibition - Video Gen - Transparent Ones - Unloved Poets - Firehose Vis',
#   'body_json': None,
#   'body_html': None,
#   'truncated_body_text': 'Lots of material here, it was a solid month of necessary escapist art viewing, reading, and playing. Kicking off with surrealis…',
#   'wordcount': 2814,
#   'postTags': [{'id': '055498ee-576a-4a8a-bd69-c244c26274f1',
#     'publication_id': 626449,
#     'name': 'occult',
#     'slug': 'occult',
#     'hidden': False},
#    {'id': '5c33f416-9046-4ced-91db-0307fa8dbfa8',
#     'publication_id': 626449,
#     'name': 'art',
#     'slug': 'art',
#     'hidden': False},
#    {'id': '954d87d3-23f1-4c50-b727-c9a40116e821',
#     'publication_id': 626449,
#     'name': 'ai',
#     'slug': 'ai',
#     'hidden': False},
#    {'id': 'cde26301-1f04-48bf-b88f-2c065594cde5',
#     'publication_id': 626449,
#     'name': 'poetry',
#     'slug': 'poetry',
#     'hidden': False}],
#   'teaser_post_eligible': True,
#   'postCountryBlocks': [],
#   'coverImagePalette': {'Vibrant': {'rgb': [138, 108, 62], 'population': 384},
#    'DarkVibrant': {'rgb': [106, 67, 41], 'population': 144},
#    'LightVibrant': {'rgb': [200, 163, 107], 'population': 29},
#    'Muted': {'rgb': [159, 136, 100], 'population': 218},
#    'DarkMuted': {'rgb': [68, 53, 48], 'population': 276},
#    'LightMuted': {'rgb': [205, 195, 175], 'population': 382}},
#   'publishedBylines': [{'id': 1346842,
#     'name': 'Lynn Cherny',
#     'handle': 'arnicas',
#     'previous_name': None,
#     'photo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/ace812d6-e878-4ba0-af77-efeacd499379_450x512.jpeg',
#     'bio': 'AI for creativity & story, games; science fiction, TV, esoterica & weirdness. Twice-a-month newsletter on Things I Think Are Awesome: https://t.co/lgcNFxxTqj',
#     'profile_set_up_at': '2021-12-23T10:37:52.777Z',
#     'publicationUsers': [{'id': 559170,
#       'user_id': 1346842,
#       'publication_id': 626449,
#       'role': 'admin',
#       'public': True,
#       'is_primary': False,
#       'publication': {'id': 626449,
#        'name': 'Things I Think Are Awesome',
#        'subdomain': 'arnicas',
#        'custom_domain': None,
#        'custom_domain_optional': False,
#        'hero_text': 'Twice a month recs on creative AI, games and narrative tools, fun NLP and data science, generative art and text, SF/fantasy books & tv, poetry, oddities & folklore.',
#        'logo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/2646b087-18d7-4a3f-aced-d4f19b93406b_1024x1024.png',
#        'author_id': 1346842,
#        'theme_var_background_pop': '#B599F1',
#        'created_at': '2021-12-21T14:42:52.852Z',
#        'rss_website_url': None,
#        'email_from_name': 'Things I Think Are Awesome',
#        'copyright': 'Lynn Cherny',
#        'founding_plan_name': 'Founding Member',
#        'community_enabled': True,
#        'invite_only': False,
#        'payments_state': 'enabled',
#        'language': None,
#        'explicit': False,
#        'is_personal_mode': False}}],
#     'twitter_screen_name': 'arnicas',
#     'is_guest': False,
#     'bestseller_tier': 100}],
#   'reaction': None,
#   'reaction_count': 7,
#   'comment_count': 2,
#   'child_comment_count': 1,
#   'audio_items': [{'post_id': 152321552,
#     'voice_id': 'en-US-ChristopherMultilingualNeural',
#     'audio_url': 'https://substack-video.s3.amazonaws.com/video_upload/post/152321552/tts/d38589ae-4025-4b37-92d0-24517aed025c/en-US-ChristopherMultilingualNeural.mp3',
#     'type': 'tts',
#     'status': 'completed'}],
#   'is_geoblocked': False,
#   'hasCashtag': False},
#  {'id': 152198089,
#   'editor_v2': False,
#   'publication_id': 626449,
#   'title': 'TITAA Recs #61: Meta Class War With Janitors',
#   'social_title': None,
#   'search_engine_title': None,
#   'search_engine_description': None,
#   'type': 'newsletter',
#   'slug': 'titaa-recs-61-meta-class-war-with',
#   'post_date': '2024-11-30T09:52:18.441Z',
#   'audience': 'only_paid',
#   'podcast_duration': None,
#   'video_upload_id': None,
#   'podcast_upload_id': None,
#   'write_comment_permissions': 'only_paid',
#   'should_send_free_preview': False,
#   'free_unlock_required': False,
#   'default_comment_sort': None,
#   'canonical_url': 'https://arnicas.substack.com/p/titaa-recs-61-meta-class-war-with',
#   'section_id': 99690,
#   'top_exclusions': [],
#   'pins': [],
#   'is_section_pinned': False,
#   'section_slug': 'titaa-recs-books-tv-games',
#   'section_name': 'TITAA Recs: Books, TV, Games',
#   'reactions': {'❤': 4},
#   'restacked_post_id': None,
#   'restacked_pub_name': None,
#   'restacked_pub_logo_url': None,
#   'subtitle': 'Books, tv, game recs for the supporters. Lots of good binge material here!',
#   'cover_image': 'https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fe333eb4c-a29d-48cc-9702-655eb892f7ad_678x609.jpeg',
#   'cover_image_is_square': False,
#   'cover_image_is_explicit': False,
#   'podcast_url': None,
#   'videoUpload': None,
#   'podcastFields': {'post_id': 152198089,
#    'podcast_episode_number': None,
#    'podcast_season_number': None,
#    'podcast_episode_type': None,
#    'should_syndicate_to_other_feed': None,
#    'syndicate_to_section_id': None,
#    'hide_from_feed': False,
#    'free_podcast_url': None,
#    'free_podcast_duration': None},
#   'podcast_preview_upload_id': None,
#   'podcastUpload': None,
#   'podcastPreviewUpload': None,
#   'voiceover_upload_id': None,
#   'voiceoverUpload': None,
#   'has_voiceover': False,
#   'description': 'Books, tv, game recs for the supporters. Lots of good binge material here!',
#   'body_json': None,
#   'body_html': None,
#   'truncated_body_text': 'This month I needed a lot of binge-y distraction, and I definitely found it on TV. A couple books paid off big time too. Books featured some recurrent themes: slavery, …',
#   'wordcount': 2198,
#   'postTags': [{'id': '0127fbd4-080d-4021-ba50-8752dd4c53a1',
#     'publication_id': 626449,
#     'name': 'games',
#     'slug': 'games',
#     'hidden': False},
#    {'id': '20e9fbeb-39ff-4e6d-bcf9-b3fdf4c76ced',
#     'publication_id': 626449,
#     'name': 'tv',
#     'slug': 'tv',
#     'hidden': False},
#    {'id': '96c0a758-e620-452e-9f28-72925f79edde',
#     'publication_id': 626449,
#     'name': 'books',
#     'slug': 'books',
#     'hidden': False}],
#   'teaser_post_eligible': True,
#   'postCountryBlocks': [],
#   'coverImagePalette': {'Vibrant': {'rgb': [150, 97, 64], 'population': 190},
#    'DarkVibrant': {'rgb': [101, 60, 28], 'population': 18},
#    'LightVibrant': {'rgb': [215.34392523364488,
#      182.50373831775698,
#      162.0560747663551],
#     'population': 0},
#    'Muted': {'rgb': [174, 147, 119], 'population': 195},
#    'DarkMuted': {'rgb': [87, 62, 45], 'population': 411},
#    'LightMuted': {'rgb': [144, 161, 163], 'population': 185}},
#   'publishedBylines': [{'id': 1346842,
#     'name': 'Lynn Cherny',
#     'handle': 'arnicas',
#     'previous_name': None,
#     'photo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/ace812d6-e878-4ba0-af77-efeacd499379_450x512.jpeg',
#     'bio': 'AI for creativity & story, games; science fiction, TV, esoterica & weirdness. Twice-a-month newsletter on Things I Think Are Awesome: https://t.co/lgcNFxxTqj',
#     'profile_set_up_at': '2021-12-23T10:37:52.777Z',
#     'publicationUsers': [{'id': 559170,
#       'user_id': 1346842,
#       'publication_id': 626449,
#       'role': 'admin',
#       'public': True,
#       'is_primary': False,
#       'publication': {'id': 626449,
#        'name': 'Things I Think Are Awesome',
#        'subdomain': 'arnicas',
#        'custom_domain': None,
#        'custom_domain_optional': False,
#        'hero_text': 'Twice a month recs on creative AI, games and narrative tools, fun NLP and data science, generative art and text, SF/fantasy books & tv, poetry, oddities & folklore.',
#        'logo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/2646b087-18d7-4a3f-aced-d4f19b93406b_1024x1024.png',
#        'author_id': 1346842,
#        'theme_var_background_pop': '#B599F1',
#        'created_at': '2021-12-21T14:42:52.852Z',
#        'rss_website_url': None,
#        'email_from_name': 'Things I Think Are Awesome',
#        'copyright': 'Lynn Cherny',
#        'founding_plan_name': 'Founding Member',
#        'community_enabled': True,
#        'invite_only': False,
#        'payments_state': 'enabled',
#        'language': None,
#        'explicit': False,
#        'is_personal_mode': False}}],
#     'twitter_screen_name': 'arnicas',
#     'is_guest': False,
#     'bestseller_tier': 100}],
#   'reaction': None,
#   'reaction_count': 4,
#   'comment_count': 2,
#   'child_comment_count': 1,
#   'audio_items': [{'post_id': 152198089,
#     'voice_id': 'en-US-ChristopherMultilingualNeural',
#     'audio_url': None,
#     'type': 'tts',
#     'status': 'paywalled'}],
#   'is_geoblocked': False,
#   'hidden': True,
#   'hasCashtag': False},
#  {'id': 151512719,
#   'editor_v2': False,
#   'publication_id': 626449,
#   'title': 'TITAA #60.5: Blueskies after Dimension X',
#   'social_title': None,
#   'search_engine_title': None,
#   'search_engine_description': None,
#   'type': 'newsletter',
#   'slug': 'titaa-605-blueskies-after-dimension',
#   'post_date': '2024-11-15T16:23:26.846Z',
#   'audience': 'only_paid',
#   'podcast_duration': None,
#   'video_upload_id': None,
#   'podcast_upload_id': None,
#   'write_comment_permissions': 'only_paid',
#   'should_send_free_preview': True,
#   'free_unlock_required': False,
#   'default_comment_sort': None,
#   'canonical_url': 'https://arnicas.substack.com/p/titaa-605-blueskies-after-dimension',
#   'section_id': None,
#   'top_exclusions': [],
#   'pins': [],
#   'is_section_pinned': False,
#   'section_slug': None,
#   'section_name': None,
#   'reactions': {'❤': 9},
#   'restacked_post_id': None,
#   'restacked_pub_name': None,
#   'restacked_pub_logo_url': None,
#   'subtitle': 'Migrating to 🦋 - Depth & Motion - Dark Folk - Liminality - Scythe of Birds - Geoff',
#   'cover_image': 'https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fa0509885-692b-4295-8efd-7027b9281d70_2000x1306.jpeg',
#   'cover_image_is_square': False,
#   'cover_image_is_explicit': False,
#   'podcast_url': None,
#   'videoUpload': None,
#   'podcastFields': {'post_id': 151512719,
#    'podcast_episode_number': None,
#    'podcast_season_number': None,
#    'podcast_episode_type': None,
#    'should_syndicate_to_other_feed': None,
#    'syndicate_to_section_id': None,
#    'hide_from_feed': False,
#    'free_podcast_url': None,
#    'free_podcast_duration': None},
#   'podcast_preview_upload_id': None,
#   'podcastUpload': None,
#   'podcastPreviewUpload': None,
#   'voiceover_upload_id': None,
#   'voiceoverUpload': None,
#   'has_voiceover': False,
#   'description': 'Migrating to 🦋 - Depth & Motion - Dark Folk - Liminality - Scythe of Birds - Geoff',
#   'body_json': None,
#   'body_html': None,
#   'truncated_body_text': 'I would have written about the surrealism exhibit at the Centre Pompidou (outstanding, ends in January), but this is already epic in length with a month’s worth of “weird & esoteric” news. Instead, I am posting a little bit above the paywall on how to set yourself up on Bluesky if you want. It’s my fav of the new sites and doesn’t make me want to shower after use.',
#   'wordcount': 3226,
#   'postTags': [{'id': '0127fbd4-080d-4021-ba50-8752dd4c53a1',
#     'publication_id': 626449,
#     'name': 'games',
#     'slug': 'games',
#     'hidden': False},
#    {'id': '545a61eb-7e63-42df-9c08-81c85550dd36',
#     'publication_id': 626449,
#     'name': 'narrative',
#     'slug': 'narrative',
#     'hidden': False},
#    {'id': '5aba9d33-3a75-4411-beb6-ef659324c107',
#     'publication_id': 626449,
#     'name': 'folklore',
#     'slug': 'folklore',
#     'hidden': False},
#    {'id': '5c33f416-9046-4ced-91db-0307fa8dbfa8',
#     'publication_id': 626449,
#     'name': 'art',
#     'slug': 'art',
#     'hidden': False},
#    {'id': '954d87d3-23f1-4c50-b727-c9a40116e821',
#     'publication_id': 626449,
#     'name': 'ai',
#     'slug': 'ai',
#     'hidden': False},
#    {'id': 'b5ff9727-f736-4d96-98b9-4fc15e614def',
#     'publication_id': 626449,
#     'name': 'esoterica',
#     'slug': 'esoterica',
#     'hidden': False}],
#   'teaser_post_eligible': True,
#   'postCountryBlocks': [],
#   'coverImagePalette': {'Vibrant': {'rgb': [177, 137, 22], 'population': 447},
#    'DarkVibrant': {'rgb': [86, 76, 11], 'population': 44},
#    'LightVibrant': {'rgb': [241, 152, 138], 'population': 183},
#    'Muted': {'rgb': [172, 127, 103], 'population': 196},
#    'DarkMuted': {'rgb': [82, 69, 41], 'population': 377},
#    'LightMuted': {'rgb': [198, 138, 161], 'population': 168}},
#   'publishedBylines': [{'id': 1346842,
#     'name': 'Lynn Cherny',
#     'handle': 'arnicas',
#     'previous_name': None,
#     'photo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/ace812d6-e878-4ba0-af77-efeacd499379_450x512.jpeg',
#     'bio': 'AI for creativity & story, games; science fiction, TV, esoterica & weirdness. Twice-a-month newsletter on Things I Think Are Awesome: https://t.co/lgcNFxxTqj',
#     'profile_set_up_at': '2021-12-23T10:37:52.777Z',
#     'publicationUsers': [{'id': 559170,
#       'user_id': 1346842,
#       'publication_id': 626449,
#       'role': 'admin',
#       'public': True,
#       'is_primary': False,
#       'publication': {'id': 626449,
#        'name': 'Things I Think Are Awesome',
#        'subdomain': 'arnicas',
#        'custom_domain': None,
#        'custom_domain_optional': False,
#        'hero_text': 'Twice a month recs on creative AI, games and narrative tools, fun NLP and data science, generative art and text, SF/fantasy books & tv, poetry, oddities & folklore.',
#        'logo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/2646b087-18d7-4a3f-aced-d4f19b93406b_1024x1024.png',
#        'author_id': 1346842,
#        'theme_var_background_pop': '#B599F1',
#        'created_at': '2021-12-21T14:42:52.852Z',
#        'rss_website_url': None,
#        'email_from_name': 'Things I Think Are Awesome',
#        'copyright': 'Lynn Cherny',
#        'founding_plan_name': 'Founding Member',
#        'community_enabled': True,
#        'invite_only': False,
#        'payments_state': 'enabled',
#        'language': None,
#        'explicit': False,
#        'is_personal_mode': False}}],
#     'twitter_screen_name': 'arnicas',
#     'is_guest': False,
#     'bestseller_tier': 100}],
#   'reaction': None,
#   'reaction_count': 9,
#   'comment_count': 0,
#   'child_comment_count': 0,
#   'audio_items': [{'post_id': 151512719,
#     'voice_id': 'en-US-ChristopherMultilingualNeural',
#     'audio_url': None,
#     'type': 'tts',
#     'status': 'paywalled'}],
#   'is_geoblocked': False,
#   'hidden': True,
#   'hasCashtag': False},
#  {'id': 150935188,
#   'editor_v2': False,
#   'publication_id': 626449,
#   'title': 'TITAA #60: Creative Gum and Rag',
#   'social_title': None,
#   'search_engine_title': None,
#   'search_engine_description': None,
#   'type': 'newsletter',
#   'slug': 'titaa-60-creative-gum-and-rag',
#   'post_date': '2024-11-01T10:57:40.821Z',
#   'audience': 'everyone',
#   'podcast_duration': None,
#   'video_upload_id': None,
#   'podcast_upload_id': None,
#   'write_comment_permissions': 'everyone',
#   'should_send_free_preview': False,
#   'free_unlock_required': False,
#   'default_comment_sort': None,
#   'canonical_url': 'https://arnicas.substack.com/p/titaa-60-creative-gum-and-rag',
#   'section_id': None,
#   'top_exclusions': [],
#   'pins': [],
#   'is_section_pinned': False,
#   'section_slug': None,
#   'section_name': None,
#   'reactions': {'❤': 10},
#   'restacked_post_id': None,
#   'restacked_pub_name': None,
#   'restacked_pub_logo_url': None,
#   'subtitle': 'Creative RAG - Lost Poetry - Minecraft Gen - SAE Papers - Narrative Agents',
#   'cover_image': 'https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fc5f4d42c-5ea2-499e-8ccd-4a64f55d8168_900x506.jpeg',
#   'cover_image_is_square': False,
#   'cover_image_is_explicit': False,
#   'podcast_url': '',
#   'videoUpload': None,
#   'podcastFields': {'post_id': 150935188,
#    'podcast_episode_number': None,
#    'podcast_season_number': None,
#    'podcast_episode_type': None,
#    'should_syndicate_to_other_feed': None,
#    'syndicate_to_section_id': None,
#    'hide_from_feed': False,
#    'free_podcast_url': None,
#    'free_podcast_duration': None},
#   'podcast_preview_upload_id': None,
#   'podcastUpload': None,
#   'podcastPreviewUpload': None,
#   'voiceover_upload_id': None,
#   'voiceoverUpload': None,
#   'has_voiceover': False,
#   'description': 'Creative RAG - Lost Poetry - Minecraft Gen - SAE Papers - Narrative Agents',
#   'body_json': None,
#   'body_html': None,
#   'truncated_body_text': 'TOC to another big issue (links on the web site):',
#   'wordcount': 3707,
#   'postTags': [{'id': '0127fbd4-080d-4021-ba50-8752dd4c53a1',
#     'publication_id': 626449,
#     'name': 'games',
#     'slug': 'games',
#     'hidden': False},
#    {'id': '545a61eb-7e63-42df-9c08-81c85550dd36',
#     'publication_id': 626449,
#     'name': 'narrative',
#     'slug': 'narrative',
#     'hidden': False},
#    {'id': '954d87d3-23f1-4c50-b727-c9a40116e821',
#     'publication_id': 626449,
#     'name': 'ai',
#     'slug': 'ai',
#     'hidden': False},
#    {'id': 'e1770120-4812-4c27-bf2c-904449199ee9',
#     'publication_id': 626449,
#     'name': 'creativity',
#     'slug': 'creativity',
#     'hidden': False},
#    {'id': 'ffd94c4b-d1a8-4a6d-8f2a-5652c5e2a942',
#     'publication_id': 626449,
#     'name': 'datascience',
#     'slug': 'datascience',
#     'hidden': False}],
#   'teaser_post_eligible': True,
#   'postCountryBlocks': [],
#   'coverImagePalette': {'Vibrant': {'rgb': [44, 124, 148], 'population': 5},
#    'DarkVibrant': {'rgb': [30, 70, 92], 'population': 463},
#    'LightVibrant': {'rgb': [152.7875, 208.0375, 224.6125], 'population': 0},
#    'Muted': {'rgb': [83, 141, 158], 'population': 122},
#    'DarkMuted': {'rgb': [48, 72, 83], 'population': 356},
#    'LightMuted': {'rgb': [167, 165, 156], 'population': 246}},
#   'publishedBylines': [{'id': 1346842,
#     'name': 'Lynn Cherny',
#     'handle': 'arnicas',
#     'previous_name': None,
#     'photo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/ace812d6-e878-4ba0-af77-efeacd499379_450x512.jpeg',
#     'bio': 'AI for creativity & story, games; science fiction, TV, esoterica & weirdness. Twice-a-month newsletter on Things I Think Are Awesome: https://t.co/lgcNFxxTqj',
#     'profile_set_up_at': '2021-12-23T10:37:52.777Z',
#     'publicationUsers': [{'id': 559170,
#       'user_id': 1346842,
#       'publication_id': 626449,
#       'role': 'admin',
#       'public': True,
#       'is_primary': False,
#       'publication': {'id': 626449,
#        'name': 'Things I Think Are Awesome',
#        'subdomain': 'arnicas',
#        'custom_domain': None,
#        'custom_domain_optional': False,
#        'hero_text': 'Twice a month recs on creative AI, games and narrative tools, fun NLP and data science, generative art and text, SF/fantasy books & tv, poetry, oddities & folklore.',
#        'logo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/2646b087-18d7-4a3f-aced-d4f19b93406b_1024x1024.png',
#        'author_id': 1346842,
#        'theme_var_background_pop': '#B599F1',
#        'created_at': '2021-12-21T14:42:52.852Z',
#        'rss_website_url': None,
#        'email_from_name': 'Things I Think Are Awesome',
#        'copyright': 'Lynn Cherny',
#        'founding_plan_name': 'Founding Member',
#        'community_enabled': True,
#        'invite_only': False,
#        'payments_state': 'enabled',
#        'language': None,
#        'explicit': False,
#        'is_personal_mode': False}}],
#     'twitter_screen_name': 'arnicas',
#     'is_guest': False,
#     'bestseller_tier': 100}],
#   'reaction': None,
#   'reaction_count': 10,
#   'comment_count': 1,
#   'child_comment_count': 1,
#   'audio_items': [{'post_id': 150935188,
#     'voice_id': 'en-US-ChristopherMultilingualNeural',
#     'audio_url': 'https://substack-video.s3.amazonaws.com/video_upload/post/150935188/tts/7732e7b4-12dd-4194-9397-f480f0ac07fc/en-US-ChristopherMultilingualNeural.mp3',
#     'type': 'tts',
#     'status': 'completed'}],
#   'is_geoblocked': False,
#   'hasCashtag': False},
#  {'id': 150895707,
#   'editor_v2': False,
#   'publication_id': 626449,
#   'title': 'TITAA Recs #60: Hybrid Humans in Weird Landscapes',
#   'social_title': None,
#   'search_engine_title': None,
#   'search_engine_description': None,
#   'type': 'newsletter',
#   'slug': 'titaa-recs-60-hybrid-humans-in-weird',
#   'post_date': '2024-10-30T13:43:48.525Z',
#   'audience': 'only_paid',
#   'podcast_duration': None,
#   'video_upload_id': None,
#   'podcast_upload_id': None,
#   'write_comment_permissions': 'only_paid',
#   'should_send_free_preview': False,
#   'free_unlock_required': False,
#   'default_comment_sort': None,
#   'canonical_url': 'https://arnicas.substack.com/p/titaa-recs-60-hybrid-humans-in-weird',
#   'section_id': 99690,
#   'top_exclusions': [],
#   'pins': [],
#   'is_section_pinned': False,
#   'section_slug': 'titaa-recs-books-tv-games',
#   'section_name': 'TITAA Recs: Books, TV, Games',
#   'reactions': {'❤': 3},
#   'restacked_post_id': None,
#   'restacked_pub_name': None,
#   'restacked_pub_logo_url': None,
#   'subtitle': 'Media recs of the month (sf & f books, tv, games) for the supporters',
#   'cover_image': 'https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fbbdc0aaf-d041-468a-b74b-4606ef309290_800x798.jpeg',
#   'cover_image_is_square': True,
#   'cover_image_is_explicit': False,
#   'podcast_url': None,
#   'videoUpload': None,
#   'podcastFields': {'post_id': 150895707,
#    'podcast_episode_number': None,
#    'podcast_season_number': None,
#    'podcast_episode_type': None,
#    'should_syndicate_to_other_feed': None,
#    'syndicate_to_section_id': None,
#    'hide_from_feed': False,
#    'free_podcast_url': None,
#    'free_podcast_duration': None},
#   'podcast_preview_upload_id': None,
#   'podcastUpload': None,
#   'podcastPreviewUpload': None,
#   'voiceover_upload_id': None,
#   'voiceoverUpload': None,
#   'has_voiceover': False,
#   'description': 'Media recs of the month (sf & f books, tv, games) for the supporters',
#   'body_json': None,
#   'body_html': None,
#   'truncated_body_text': 'Books ⭐️ The Cautious Traveller’s Guide to the Wastelands by Sarah Brooks (fantasy). This reminded me of the Southern Reach series (see below), but merged with Snowpiercer…',
#   'wordcount': 1412,
#   'postTags': [{'id': '20e9fbeb-39ff-4e6d-bcf9-b3fdf4c76ced',
#     'publication_id': 626449,
#     'name': 'tv',
#     'slug': 'tv',
#     'hidden': False},
#    {'id': '96c0a758-e620-452e-9f28-72925f79edde',
#     'publication_id': 626449,
#     'name': 'books',
#     'slug': 'books',
#     'hidden': False},
#    {'id': 'acf844a8-14e6-4d81-8361-15fecf6d07f5',
#     'publication_id': 626449,
#     'name': 'sf&f',
#     'slug': 'sf-and-f',
#     'hidden': False},
#    {'id': 'ef60306b-ebc8-4c08-a5bd-7b45f2385ca4',
#     'publication_id': 626449,
#     'name': 'reviews',
#     'slug': 'reviews',
#     'hidden': False}],
#   'teaser_post_eligible': True,
#   'postCountryBlocks': [],
#   'coverImagePalette': {'Vibrant': {'rgb': [209.7580645161291,
#      143.9516129032258,
#      45.2419354838709],
#     'population': 0},
#    'DarkVibrant': {'rgb': [109.07419354838714,
#      74.85483870967741,
#      23.525806451612866],
#     'population': 0},
#    'LightVibrant': {'rgb': [244, 228, 204], 'population': 1},
#    'Muted': {'rgb': [134, 127, 114], 'population': 281},
#    'DarkMuted': {'rgb': [73, 68, 55], 'population': 359},
#    'LightMuted': {'rgb': [197, 184, 165], 'population': 101}},
#   'publishedBylines': [{'id': 1346842,
#     'name': 'Lynn Cherny',
#     'handle': 'arnicas',
#     'previous_name': None,
#     'photo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/ace812d6-e878-4ba0-af77-efeacd499379_450x512.jpeg',
#     'bio': 'AI for creativity & story, games; science fiction, TV, esoterica & weirdness. Twice-a-month newsletter on Things I Think Are Awesome: https://t.co/lgcNFxxTqj',
#     'profile_set_up_at': '2021-12-23T10:37:52.777Z',
#     'publicationUsers': [{'id': 559170,
#       'user_id': 1346842,
#       'publication_id': 626449,
#       'role': 'admin',
#       'public': True,
#       'is_primary': False,
#       'publication': {'id': 626449,
#        'name': 'Things I Think Are Awesome',
#        'subdomain': 'arnicas',
#        'custom_domain': None,
#        'custom_domain_optional': False,
#        'hero_text': 'Twice a month recs on creative AI, games and narrative tools, fun NLP and data science, generative art and text, SF/fantasy books & tv, poetry, oddities & folklore.',
#        'logo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/2646b087-18d7-4a3f-aced-d4f19b93406b_1024x1024.png',
#        'author_id': 1346842,
#        'theme_var_background_pop': '#B599F1',
#        'created_at': '2021-12-21T14:42:52.852Z',
#        'rss_website_url': None,
#        'email_from_name': 'Things I Think Are Awesome',
#        'copyright': 'Lynn Cherny',
#        'founding_plan_name': 'Founding Member',
#        'community_enabled': True,
#        'invite_only': False,
#        'payments_state': 'enabled',
#        'language': None,
#        'explicit': False,
#        'is_personal_mode': False}}],
#     'twitter_screen_name': 'arnicas',
#     'is_guest': False,
#     'bestseller_tier': 100}],
#   'reaction': None,
#   'reaction_count': 3,
#   'comment_count': 7,
#   'child_comment_count': 3,
#   'audio_items': [{'post_id': 150895707,
#     'voice_id': 'en-US-ChristopherMultilingualNeural',
#     'audio_url': None,
#     'type': 'tts',
#     'status': 'paywalled'}],
#   'is_geoblocked': False,
#   'hidden': True,
#   'hasCashtag': False},
#  {'id': 150091558,
#   'editor_v2': False,
#   'publication_id': 626449,
#   'title': 'TITAA #59.5: The Owl Treasure Hunt',
#   'social_title': None,
#   'search_engine_title': None,
#   'search_engine_description': None,
#   'type': 'newsletter',
#   'slug': 'titaa-595-the-owl-treasure-hunt',
#   'post_date': '2024-10-15T14:58:45.377Z',
#   'audience': 'only_paid',
#   'podcast_duration': None,
#   'video_upload_id': None,
#   'podcast_upload_id': None,
#   'write_comment_permissions': 'only_paid',
#   'should_send_free_preview': True,
#   'free_unlock_required': False,
#   'default_comment_sort': None,
#   'canonical_url': 'https://arnicas.substack.com/p/titaa-595-the-owl-treasure-hunt',
#   'section_id': None,
#   'top_exclusions': [],
#   'pins': [],
#   'is_section_pinned': False,
#   'section_slug': None,
#   'section_name': None,
#   'reactions': {'❤': 4},
#   'restacked_post_id': None,
#   'restacked_pub_name': None,
#   'restacked_pub_logo_url': None,
#   'subtitle': 'Chouetteurs - AI Video - Real-time - Time & Space - Uncooperative Poets - Fun & Sad Databases',
#   'cover_image': 'https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2F9f578e94-9929-4b7b-b782-babf9292635c_800x333.jpeg',
#   'cover_image_is_square': False,
#   'cover_image_is_explicit': False,
#   'podcast_url': None,
#   'videoUpload': None,
#   'podcastFields': {'post_id': 150091558,
#    'podcast_episode_number': None,
#    'podcast_season_number': None,
#    'podcast_episode_type': None,
#    'should_syndicate_to_other_feed': None,
#    'syndicate_to_section_id': None,
#    'hide_from_feed': False,
#    'free_podcast_url': None,
#    'free_podcast_duration': None},
#   'podcast_preview_upload_id': None,
#   'podcastUpload': None,
#   'podcastPreviewUpload': None,
#   'voiceover_upload_id': None,
#   'voiceoverUpload': None,
#   'has_voiceover': False,
#   'description': 'Chouetteurs - AI Video - Real-time - Time & Space - Uncooperative Poets - Fun & Sad Databases',
#   'body_json': None,
#   'body_html': None,
#   'truncated_body_text': 'Because it’s the weird mid-month issue, let’s cover the French treasure hunt news! And then a banger of a creative AI tools update, plus the mid-month weird links—I got my enthusiasm back.',
#   'wordcount': 2730,
#   'postTags': [{'id': '0127fbd4-080d-4021-ba50-8752dd4c53a1',
#     'publication_id': 626449,
#     'name': 'games',
#     'slug': 'games',
#     'hidden': False},
#    {'id': '5c33f416-9046-4ced-91db-0307fa8dbfa8',
#     'publication_id': 626449,
#     'name': 'art',
#     'slug': 'art',
#     'hidden': False},
#    {'id': '6edb6cb2-79e7-4e2b-9814-cd441aeb097d',
#     'publication_id': 626449,
#     'name': 'weird',
#     'slug': 'weird',
#     'hidden': False},
#    {'id': '954d87d3-23f1-4c50-b727-c9a40116e821',
#     'publication_id': 626449,
#     'name': 'ai',
#     'slug': 'ai',
#     'hidden': False},
#    {'id': '9bf1ab09-723d-4e3e-93ab-ef08b81f5a93',
#     'publication_id': 626449,
#     'name': 'video',
#     'slug': 'video',
#     'hidden': False},
#    {'id': 'e1770120-4812-4c27-bf2c-904449199ee9',
#     'publication_id': 626449,
#     'name': 'creativity',
#     'slug': 'creativity',
#     'hidden': False}],
#   'teaser_post_eligible': True,
#   'postCountryBlocks': [],
#   'coverImagePalette': {'Vibrant': {'rgb': [178, 143, 76], 'population': 5},
#    'DarkVibrant': {'rgb': [89, 60, 30], 'population': 3},
#    'LightVibrant': {'rgb': [231, 215, 156], 'population': 27},
#    'Muted': {'rgb': [180, 132, 84], 'population': 1},
#    'DarkMuted': {'rgb': [76, 84, 52], 'population': 1},
#    'LightMuted': {'rgb': [205, 188, 156], 'population': 62}},
#   'publishedBylines': [{'id': 1346842,
#     'name': 'Lynn Cherny',
#     'handle': 'arnicas',
#     'previous_name': None,
#     'photo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/ace812d6-e878-4ba0-af77-efeacd499379_450x512.jpeg',
#     'bio': 'AI for creativity & story, games; science fiction, TV, esoterica & weirdness. Twice-a-month newsletter on Things I Think Are Awesome: https://t.co/lgcNFxxTqj',
#     'profile_set_up_at': '2021-12-23T10:37:52.777Z',
#     'publicationUsers': [{'id': 559170,
#       'user_id': 1346842,
#       'publication_id': 626449,
#       'role': 'admin',
#       'public': True,
#       'is_primary': False,
#       'publication': {'id': 626449,
#        'name': 'Things I Think Are Awesome',
#        'subdomain': 'arnicas',
#        'custom_domain': None,
#        'custom_domain_optional': False,
#        'hero_text': 'Twice a month recs on creative AI, games and narrative tools, fun NLP and data science, generative art and text, SF/fantasy books & tv, poetry, oddities & folklore.',
#        'logo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/2646b087-18d7-4a3f-aced-d4f19b93406b_1024x1024.png',
#        'author_id': 1346842,
#        'theme_var_background_pop': '#B599F1',
#        'created_at': '2021-12-21T14:42:52.852Z',
#        'rss_website_url': None,
#        'email_from_name': 'Things I Think Are Awesome',
#        'copyright': 'Lynn Cherny',
#        'founding_plan_name': 'Founding Member',
#        'community_enabled': True,
#        'invite_only': False,
#        'payments_state': 'enabled',
#        'language': None,
#        'explicit': False,
#        'is_personal_mode': False}}],
#     'twitter_screen_name': 'arnicas',
#     'is_guest': False,
#     'bestseller_tier': 100}],
#   'reaction': None,
#   'reaction_count': 4,
#   'comment_count': 2,
#   'child_comment_count': 1,
#   'audio_items': [{'post_id': 150091558,
#     'voice_id': 'en-US-ChristopherMultilingualNeural',
#     'audio_url': None,
#     'type': 'tts',
#     'status': 'paywalled'}],
#   'is_geoblocked': False,
#   'hidden': True,
#   'hasCashtag': False},
#  {'id': 149481675,
#   'editor_v2': False,
#   'publication_id': 626449,
#   'title': 'TITAA #59: Citizen Satellite Glyphs',
#   'social_title': None,
#   'search_engine_title': None,
#   'search_engine_description': None,
#   'type': 'newsletter',
#   'slug': 'titaa-59-citizen-satellite-glyphs',
#   'post_date': '2024-09-30T17:43:36.232Z',
#   'audience': 'everyone',
#   'podcast_duration': None,
#   'video_upload_id': None,
#   'podcast_upload_id': None,
#   'write_comment_permissions': 'everyone',
#   'should_send_free_preview': False,
#   'free_unlock_required': False,
#   'default_comment_sort': None,
#   'canonical_url': 'https://arnicas.substack.com/p/titaa-59-citizen-satellite-glyphs',
#   'section_id': None,
#   'top_exclusions': [],
#   'pins': [],
#   'is_section_pinned': False,
#   'section_slug': None,
#   'section_name': None,
#   'reactions': {'❤': 7},
#   'restacked_post_id': None,
#   'restacked_pub_name': None,
#   'restacked_pub_logo_url': None,
#   'subtitle': 'Zelda Worlds - Creative/Multimodal Writing - Frankenstein Vis - Skydrop - Tutorials - Weather Landscape',
#   'cover_image': 'https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2F775f309c-b532-4382-ba60-6906e4fdb2d1_988x342.png',
#   'cover_image_is_square': False,
#   'cover_image_is_explicit': False,
#   'podcast_url': '',
#   'videoUpload': None,
#   'podcastFields': {'post_id': 149481675,
#    'podcast_episode_number': None,
#    'podcast_season_number': None,
#    'podcast_episode_type': None,
#    'should_syndicate_to_other_feed': None,
#    'syndicate_to_section_id': None,
#    'hide_from_feed': False,
#    'free_podcast_url': None,
#    'free_podcast_duration': None},
#   'podcast_preview_upload_id': None,
#   'podcastUpload': None,
#   'podcastPreviewUpload': None,
#   'voiceover_upload_id': None,
#   'voiceoverUpload': None,
#   'has_voiceover': False,
#   'description': 'Zelda Worlds - Creative/Multimodal Writing - Frankenstein Vis - Skydrop - Tutorials - Weather Landscape',
#   'body_json': None,
#   'body_html': None,
#   'truncated_body_text': 'Table of Contents (links on Substack page):',
#   'wordcount': 2973,
#   'postTags': [{'id': '0127fbd4-080d-4021-ba50-8752dd4c53a1',
#     'publication_id': 626449,
#     'name': 'games',
#     'slug': 'games',
#     'hidden': False},
#    {'id': '545a61eb-7e63-42df-9c08-81c85550dd36',
#     'publication_id': 626449,
#     'name': 'narrative',
#     'slug': 'narrative',
#     'hidden': False},
#    {'id': '6c48f13c-e8fb-4198-a0bd-0db547ad9c90',
#     'publication_id': 626449,
#     'name': 'datavis',
#     'slug': 'datavis',
#     'hidden': False},
#    {'id': '954d87d3-23f1-4c50-b727-c9a40116e821',
#     'publication_id': 626449,
#     'name': 'ai',
#     'slug': 'ai',
#     'hidden': False},
#    {'id': '96c0a758-e620-452e-9f28-72925f79edde',
#     'publication_id': 626449,
#     'name': 'books',
#     'slug': 'books',
#     'hidden': False},
#    {'id': 'be7333ac-b1b4-459b-b341-0b1336ee6766',
#     'publication_id': 626449,
#     'name': 'archaeology',
#     'slug': 'archaeology',
#     'hidden': False}],
#   'teaser_post_eligible': True,
#   'postCountryBlocks': [],
#   'coverImagePalette': {'Vibrant': {'rgb': [135.59523809523813,
#      135.59523809523813,
#      119.40476190476188],
#     'population': 0},
#    'DarkVibrant': {'rgb': [70.50952380952381,
#      70.50952380952381,
#      62.09047619047619],
#     'population': 0},
#    'LightVibrant': {'rgb': [192.90952380952382,
#      192.90952380952382,
#      184.49047619047616],
#     'population': 0},
#    'Muted': {'rgb': [132, 132, 124], 'population': 759},
#    'DarkMuted': {'rgb': [116, 116, 100], 'population': 1},
#    'LightMuted': {'rgb': [196, 196, 188], 'population': 23}},
#   'publishedBylines': [{'id': 1346842,
#     'name': 'Lynn Cherny',
#     'handle': 'arnicas',
#     'previous_name': None,
#     'photo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/ace812d6-e878-4ba0-af77-efeacd499379_450x512.jpeg',
#     'bio': 'AI for creativity & story, games; science fiction, TV, esoterica & weirdness. Twice-a-month newsletter on Things I Think Are Awesome: https://t.co/lgcNFxxTqj',
#     'profile_set_up_at': '2021-12-23T10:37:52.777Z',
#     'publicationUsers': [{'id': 559170,
#       'user_id': 1346842,
#       'publication_id': 626449,
#       'role': 'admin',
#       'public': True,
#       'is_primary': False,
#       'publication': {'id': 626449,
#        'name': 'Things I Think Are Awesome',
#        'subdomain': 'arnicas',
#        'custom_domain': None,
#        'custom_domain_optional': False,
#        'hero_text': 'Twice a month recs on creative AI, games and narrative tools, fun NLP and data science, generative art and text, SF/fantasy books & tv, poetry, oddities & folklore.',
#        'logo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/2646b087-18d7-4a3f-aced-d4f19b93406b_1024x1024.png',
#        'author_id': 1346842,
#        'theme_var_background_pop': '#B599F1',
#        'created_at': '2021-12-21T14:42:52.852Z',
#        'rss_website_url': None,
#        'email_from_name': 'Things I Think Are Awesome',
#        'copyright': 'Lynn Cherny',
#        'founding_plan_name': 'Founding Member',
#        'community_enabled': True,
#        'invite_only': False,
#        'payments_state': 'enabled',
#        'language': None,
#        'explicit': False,
#        'is_personal_mode': False}}],
#     'twitter_screen_name': 'arnicas',
#     'is_guest': False,
#     'bestseller_tier': 100}],
#   'reaction': None,
#   'reaction_count': 7,
#   'comment_count': 0,
#   'child_comment_count': 0,
#   'audio_items': [{'post_id': 149481675,
#     'voice_id': 'en-US-CoraMultilingualNeural',
#     'audio_url': 'https://substack-video.s3.amazonaws.com/video_upload/post/149481675/tts/f47b2c72-cc4b-4873-9ad5-38fdfedd763a/en-US-CoraMultilingualNeural.mp3',
#     'type': 'tts',
#     'status': 'completed'}],
#   'is_geoblocked': False,
#   'hasCashtag': False},
#  {'id': 149481772,
#   'editor_v2': False,
#   'publication_id': 626449,
#   'title': 'TITAA #59 Recs: Noir Alien Roads',
#   'social_title': None,
#   'search_engine_title': None,
#   'search_engine_description': None,
#   'type': 'newsletter',
#   'slug': 'titaa-59-recs-noir-alien-roads',
#   'post_date': '2024-09-29T19:34:19.194Z',
#   'audience': 'only_paid',
#   'podcast_duration': None,
#   'video_upload_id': None,
#   'podcast_upload_id': None,
#   'write_comment_permissions': 'only_paid',
#   'should_send_free_preview': False,
#   'free_unlock_required': False,
#   'default_comment_sort': None,
#   'canonical_url': 'https://arnicas.substack.com/p/titaa-59-recs-noir-alien-roads',
#   'section_id': 99690,
#   'top_exclusions': [],
#   'pins': [],
#   'is_section_pinned': False,
#   'section_slug': 'titaa-recs-books-tv-games',
#   'section_name': 'TITAA Recs: Books, TV, Games',
#   'reactions': {'❤': 7},
#   'restacked_post_id': None,
#   'restacked_pub_name': None,
#   'restacked_pub_logo_url': None,
#   'subtitle': 'Some media recs (books, tv, games) for the paying supporters, with detail!',
#   'cover_image': 'https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fd63b6cfa-ff2b-4fc6-ba20-1f5cbcdcb18d_767x583.png',
#   'cover_image_is_square': False,
#   'cover_image_is_explicit': False,
#   'podcast_url': None,
#   'videoUpload': None,
#   'podcastFields': {'post_id': 149481772,
#    'podcast_episode_number': None,
#    'podcast_season_number': None,
#    'podcast_episode_type': None,
#    'should_syndicate_to_other_feed': None,
#    'syndicate_to_section_id': None,
#    'hide_from_feed': False,
#    'free_podcast_url': None,
#    'free_podcast_duration': None},
#   'podcast_preview_upload_id': None,
#   'podcastUpload': None,
#   'podcastPreviewUpload': None,
#   'voiceover_upload_id': None,
#   'voiceoverUpload': None,
#   'has_voiceover': False,
#   'description': 'Some media recs (books, tv, games) for the paying supporters, with detail!',
#   'body_json': None,
#   'body_html': None,
#   'truncated_body_text': 'I’m feeling a bit poorly so not sure how ambitious the end-of-month news post will be tomorrow;…',
#   'wordcount': 1692,
#   'postTags': [{'id': '0127fbd4-080d-4021-ba50-8752dd4c53a1',
#     'publication_id': 626449,
#     'name': 'games',
#     'slug': 'games',
#     'hidden': False},
#    {'id': '17703ea1-1c88-4a2c-9a12-d37393f5801b',
#     'publication_id': 626449,
#     'name': 'books=',
#     'slug': 'books-954',
#     'hidden': False},
#    {'id': '20e9fbeb-39ff-4e6d-bcf9-b3fdf4c76ced',
#     'publication_id': 626449,
#     'name': 'tv',
#     'slug': 'tv',
#     'hidden': False}],
#   'teaser_post_eligible': True,
#   'postCountryBlocks': [],
#   'coverImagePalette': {'Vibrant': {'rgb': [172, 140, 68], 'population': 1},
#    'DarkVibrant': {'rgb': [84, 47, 27], 'population': 11},
#    'LightVibrant': {'rgb': [217, 204, 172], 'population': 17},
#    'Muted': {'rgb': [163, 139, 87], 'population': 39},
#    'DarkMuted': {'rgb': [82, 56, 47], 'population': 287},
#    'LightMuted': {'rgb': [190, 194, 197], 'population': 62}},
#   'publishedBylines': [{'id': 1346842,
#     'name': 'Lynn Cherny',
#     'handle': 'arnicas',
#     'previous_name': None,
# ...
#   'restacked_pub_logo_url': None,
#   'subtitle': 'MJ Character - Coercing LLMs - LSD - DataVis/NLP - Weird Games - A Goldfish',
#   'cover_image': 'https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2F25aac8b3-11a4-4820-b308-c2a013089f69_600x811.jpeg',
#   'cover_image_is_square': False,
#   'cover_image_is_explicit': False,
#   'podcast_url': None,
#   'videoUpload': None,
#   'podcastFields': {'post_id': 142606228,
#    'podcast_episode_number': None,
#    'podcast_season_number': None,
#    'podcast_episode_type': None,
#    'should_syndicate_to_other_feed': None,
#    'syndicate_to_section_id': None,
#    'hide_from_feed': False,
#    'free_podcast_url': None,
#    'free_podcast_duration': None},
#   'podcast_preview_upload_id': None,
#   'podcastUpload': None,
#   'podcastPreviewUpload': None,
#   'voiceover_upload_id': None,
#   'voiceoverUpload': None,
#   'has_voiceover': False,
#   'description': 'MJ Character - Coercing LLMs - LSD - DataVis/NLP - Weird Games - A Goldfish',
#   'body_json': None,
#   'body_html': None,
#   'truncated_body_text': 'For the mid-month “weirder” content, I am opening with a bunch of items on weird language model prompt behaviors I’ve seen recently. To set the stage, there’s a piece on “Thinking About AI With Stanislaw Lem',
#   'wordcount': 3406,
#   'postTags': [{'id': '0127fbd4-080d-4021-ba50-8752dd4c53a1',
#     'publication_id': 626449,
#     'name': 'games',
#     'slug': 'games',
#     'hidden': False},
#    {'id': '545a61eb-7e63-42df-9c08-81c85550dd36',
#     'publication_id': 626449,
#     'name': 'narrative',
#     'slug': 'narrative',
#     'hidden': False},
#    {'id': '5c33f416-9046-4ced-91db-0307fa8dbfa8',
#     'publication_id': 626449,
#     'name': 'art',
#     'slug': 'art',
#     'hidden': False},
#    {'id': '6edb6cb2-79e7-4e2b-9814-cd441aeb097d',
#     'publication_id': 626449,
#     'name': 'weird',
#     'slug': 'weird',
#     'hidden': False},
#    {'id': '954d87d3-23f1-4c50-b727-c9a40116e821',
#     'publication_id': 626449,
#     'name': 'ai',
#     'slug': 'ai',
#     'hidden': False},
#    {'id': 'b5ff9727-f736-4d96-98b9-4fc15e614def',
#     'publication_id': 626449,
#     'name': 'esoterica',
#     'slug': 'esoterica',
#     'hidden': False},
#    {'id': 'bbdc0e28-78eb-476c-9e10-445c9c4b83cd',
#     'publication_id': 626449,
#     'name': 'nlp',
#     'slug': 'nlp',
#     'hidden': False},
#    {'id': 'ffd94c4b-d1a8-4a6d-8f2a-5652c5e2a942',
#     'publication_id': 626449,
#     'name': 'datascience',
#     'slug': 'datascience',
#     'hidden': False}],
#   'teaser_post_eligible': True,
#   'postCountryBlocks': [],
#   'coverImagePalette': {'Vibrant': {'rgb': [204, 175, 147], 'population': 37},
#    'DarkVibrant': {'rgb': [93, 69, 36], 'population': 7},
#    'LightVibrant': {'rgb': [212, 180, 160], 'population': 33},
#    'Muted': {'rgb': [148, 125, 101], 'population': 221},
#    'DarkMuted': {'rgb': [92, 60, 44], 'population': 3},
#    'LightMuted': {'rgb': [213, 190, 174], 'population': 148}},
#   'publishedBylines': [{'id': 1346842,
#     'name': 'Lynn Cherny',
#     'handle': 'arnicas',
#     'previous_name': None,
#     'photo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/ace812d6-e878-4ba0-af77-efeacd499379_450x512.jpeg',
#     'bio': 'AI for creativity & story, games; science fiction, TV, esoterica & weirdness. Twice-a-month newsletter on Things I Think Are Awesome: https://t.co/lgcNFxxTqj',
#     'profile_set_up_at': '2021-12-23T10:37:52.777Z',
#     'publicationUsers': [{'id': 559170,
#       'user_id': 1346842,
#       'publication_id': 626449,
#       'role': 'admin',
#       'public': True,
#       'is_primary': False,
#       'publication': {'id': 626449,
#        'name': 'Things I Think Are Awesome',
#        'subdomain': 'arnicas',
#        'custom_domain': None,
#        'custom_domain_optional': False,
#        'hero_text': 'Twice a month recs on creative AI, games and narrative tools, fun NLP and data science, generative art and text, SF/fantasy books & tv, poetry, oddities & folklore.',
#        'logo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/2646b087-18d7-4a3f-aced-d4f19b93406b_1024x1024.png',
#        'author_id': 1346842,
#        'theme_var_background_pop': '#B599F1',
#        'created_at': '2021-12-21T14:42:52.852Z',
#        'rss_website_url': None,
#        'email_from_name': 'Things I Think Are Awesome',
#        'copyright': 'Lynn Cherny',
#        'founding_plan_name': 'Founding Member',
#        'community_enabled': True,
#        'invite_only': False,
#        'payments_state': 'enabled',
#        'language': None,
#        'explicit': False,
#        'is_personal_mode': False}}],
#     'twitter_screen_name': 'arnicas',
#     'is_guest': False,
#     'bestseller_tier': 100}],
#   'reaction': None,
#   'reaction_count': 5,
#   'comment_count': 0,
#   'child_comment_count': 0,
#   'audio_items': [{'post_id': 142606228,
#     'voice_id': 'en-US-JennyNeural',
#     'audio_url': None,
#     'type': 'tts',
#     'status': 'paywalled'}],
#   'is_geoblocked': False,
#   'hidden': True,
#   'hasCashtag': False},
#  {'id': 142142236,
#   'editor_v2': False,
#   'publication_id': 626449,
#   'title': 'TITAA #52: Latent Ghosts Fiddling ',
#   'social_title': None,
#   'search_engine_title': None,
#   'search_engine_description': None,
#   'type': 'newsletter',
#   'slug': 'titaa-52-latent-ghosts-fiddling',
#   'post_date': '2024-03-01T14:54:27.524Z',
#   'audience': 'everyone',
#   'podcast_duration': None,
#   'video_upload_id': None,
#   'podcast_upload_id': None,
#   'write_comment_permissions': 'everyone',
#   'should_send_free_preview': False,
#   'free_unlock_required': False,
#   'default_comment_sort': None,
#   'canonical_url': 'https://arnicas.substack.com/p/titaa-52-latent-ghosts-fiddling',
#   'section_id': None,
#   'top_exclusions': [],
#   'pins': [],
#   'is_section_pinned': False,
#   'section_slug': None,
#   'section_name': None,
#   'reactions': {'❤': 10},
#   'restacked_post_id': None,
#   'restacked_pub_name': None,
#   'restacked_pub_logo_url': None,
#   'subtitle': 'Video Gen Fun - Image Gen Alts - NPC Labor - Embedding Vis - Dune Ornithopters - Game AI Reports',
#   'cover_image': 'https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Ffe80cc1c-be27-4d29-b245-7cce237e5d6c_900x595.jpeg',
#   'cover_image_is_square': False,
#   'cover_image_is_explicit': False,
#   'podcast_url': '',
#   'videoUpload': None,
#   'podcastFields': {'post_id': 142142236,
#    'podcast_episode_number': None,
#    'podcast_season_number': None,
#    'podcast_episode_type': None,
#    'should_syndicate_to_other_feed': None,
#    'syndicate_to_section_id': None,
#    'hide_from_feed': False,
#    'free_podcast_url': None,
#    'free_podcast_duration': None},
#   'podcast_preview_upload_id': None,
#   'podcastUpload': None,
#   'podcastPreviewUpload': None,
#   'voiceover_upload_id': None,
#   'voiceoverUpload': None,
#   'has_voiceover': False,
#   'description': 'Video Gen Fun - Image Gen Alts - NPC Labor - Embedding Vis - Dune Ornithopters - Game AI Reports',
#   'body_json': None,
#   'body_html': None,
#   'truncated_body_text': 'I’m a day late, so no intro article! I’ve already used up my time for the week. Just a ton of news, a lot has happened in AI and tool-land this past couple of week…',
#   'wordcount': 3799,
#   'postTags': [{'id': '0127fbd4-080d-4021-ba50-8752dd4c53a1',
#     'publication_id': 626449,
#     'name': 'games',
#     'slug': 'games',
#     'hidden': False},
#    {'id': '5c33f416-9046-4ced-91db-0307fa8dbfa8',
#     'publication_id': 626449,
#     'name': 'art',
#     'slug': 'art',
#     'hidden': False},
#    {'id': '954d87d3-23f1-4c50-b727-c9a40116e821',
#     'publication_id': 626449,
#     'name': 'ai',
#     'slug': 'ai',
#     'hidden': False},
#    {'id': '96c0a758-e620-452e-9f28-72925f79edde',
#     'publication_id': 626449,
#     'name': 'books',
#     'slug': 'books',
#     'hidden': False},
#    {'id': '9bf1ab09-723d-4e3e-93ab-ef08b81f5a93',
#     'publication_id': 626449,
#     'name': 'video',
#     'slug': 'video',
#     'hidden': False}],
#   'teaser_post_eligible': True,
#   'postCountryBlocks': [],
#   'coverImagePalette': {'Vibrant': {'rgb': [26, 132, 158], 'population': 136},
#    'DarkVibrant': {'rgb': [18.73695652173913,
#      95.12608695652176,
#      113.86304347826088],
#     'population': 0},
#    'LightVibrant': {'rgb': [184, 220, 233], 'population': 6},
#    'Muted': {'rgb': [87, 113, 147], 'population': 91},
#    'DarkMuted': {'rgb': [44, 47, 78], 'population': 23},
#    'LightMuted': {'rgb': [178, 196, 207], 'population': 346}},
#   'publishedBylines': [{'id': 1346842,
#     'name': 'Lynn Cherny',
#     'handle': 'arnicas',
#     'previous_name': None,
#     'photo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/ace812d6-e878-4ba0-af77-efeacd499379_450x512.jpeg',
#     'bio': 'AI for creativity & story, games; science fiction, TV, esoterica & weirdness. Twice-a-month newsletter on Things I Think Are Awesome: https://t.co/lgcNFxxTqj',
#     'profile_set_up_at': '2021-12-23T10:37:52.777Z',
#     'publicationUsers': [{'id': 559170,
#       'user_id': 1346842,
#       'publication_id': 626449,
#       'role': 'admin',
#       'public': True,
#       'is_primary': False,
#       'publication': {'id': 626449,
#        'name': 'Things I Think Are Awesome',
#        'subdomain': 'arnicas',
#        'custom_domain': None,
#        'custom_domain_optional': False,
#        'hero_text': 'Twice a month recs on creative AI, games and narrative tools, fun NLP and data science, generative art and text, SF/fantasy books & tv, poetry, oddities & folklore.',
#        'logo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/2646b087-18d7-4a3f-aced-d4f19b93406b_1024x1024.png',
#        'author_id': 1346842,
#        'theme_var_background_pop': '#B599F1',
#        'created_at': '2021-12-21T14:42:52.852Z',
#        'rss_website_url': None,
#        'email_from_name': 'Things I Think Are Awesome',
#        'copyright': 'Lynn Cherny',
#        'founding_plan_name': 'Founding Member',
#        'community_enabled': True,
#        'invite_only': False,
#        'payments_state': 'enabled',
#        'language': None,
#        'explicit': False,
#        'is_personal_mode': False}}],
#     'twitter_screen_name': 'arnicas',
#     'is_guest': False,
#     'bestseller_tier': 100}],
#   'reaction': None,
#   'reaction_count': 10,
#   'comment_count': 6,
#   'child_comment_count': 2,
#   'audio_items': [{'post_id': 142142236,
#     'voice_id': 'en-US-JennyNeural',
#     'audio_url': 'https://substack-video.s3.amazonaws.com/video_upload/post/142142236/tts/ee14bf73-2f84-45c0-bb78-fe8005a53874/en-US-JennyNeural.mp3',
#     'type': 'tts',
#     'status': 'completed'}],
#   'is_geoblocked': False,
#   'hasCashtag': False},
#  {'id': 142168745,
#   'editor_v2': False,
#   'publication_id': 626449,
#   'title': 'TITAA #52 Recs: Ghosts & Fairies, Crashing on Dune, Delicious Monsters',
#   'social_title': None,
#   'search_engine_title': None,
#   'search_engine_description': None,
#   'type': 'newsletter',
#   'slug': 'titaa-52-recs-ghosts-and-fairies',
#   'post_date': '2024-02-29T17:49:19.826Z',
#   'audience': 'only_paid',
#   'podcast_duration': None,
#   'video_upload_id': None,
#   'podcast_upload_id': None,
#   'write_comment_permissions': 'only_paid',
#   'should_send_free_preview': False,
#   'free_unlock_required': False,
#   'default_comment_sort': None,
#   'canonical_url': 'https://arnicas.substack.com/p/titaa-52-recs-ghosts-and-fairies',
#   'section_id': 99690,
#   'top_exclusions': [],
#   'pins': [],
#   'is_section_pinned': False,
#   'section_slug': 'titaa-recs-books-tv-games',
#   'section_name': 'TITAA Recs: Books, TV, Games',
#   'reactions': {'❤': 3},
#   'restacked_post_id': None,
#   'restacked_pub_name': None,
#   'restacked_pub_logo_url': None,
#   'subtitle': 'The book/tv/games recs, long form, for the supporters.',
#   'cover_image': 'https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2F91acbc7d-1749-4d1b-bb3b-6df31e445f3b_762x480.png',
#   'cover_image_is_square': False,
#   'cover_image_is_explicit': False,
#   'podcast_url': None,
#   'videoUpload': None,
#   'podcastFields': {'post_id': 142168745,
#    'podcast_episode_number': None,
#    'podcast_season_number': None,
#    'podcast_episode_type': None,
#    'should_syndicate_to_other_feed': None,
#    'syndicate_to_section_id': None,
#    'hide_from_feed': False,
#    'free_podcast_url': None,
#    'free_podcast_duration': None},
#   'podcast_preview_upload_id': None,
#   'podcastUpload': None,
#   'podcastPreviewUpload': None,
#   'voiceover_upload_id': None,
#   'voiceoverUpload': None,
#   'has_voiceover': False,
#   'description': 'The book/tv/games recs, long form, for the supporters.',
#   'body_json': None,
#   'body_html': None,
#   'truncated_body_text': 'Oof — I am running late on the main post, which is long (of course) and it’s a short month. Find below all my med…',
#   'wordcount': 1559,
#   'postTags': [{'id': '0127fbd4-080d-4021-ba50-8752dd4c53a1',
#     'publication_id': 626449,
#     'name': 'games',
#     'slug': 'games',
#     'hidden': False},
#    {'id': '20e9fbeb-39ff-4e6d-bcf9-b3fdf4c76ced',
#     'publication_id': 626449,
#     'name': 'tv',
#     'slug': 'tv',
#     'hidden': False},
#    {'id': '96c0a758-e620-452e-9f28-72925f79edde',
#     'publication_id': 626449,
#     'name': 'books',
#     'slug': 'books',
#     'hidden': False},
#    {'id': 'ef60306b-ebc8-4c08-a5bd-7b45f2385ca4',
#     'publication_id': 626449,
#     'name': 'reviews',
#     'slug': 'reviews',
#     'hidden': False}],
#   'teaser_post_eligible': True,
#   'postCountryBlocks': [],
#   'coverImagePalette': {'Vibrant': {'rgb': [162, 109, 76], 'population': 76},
#    'DarkVibrant': {'rgb': [99, 57, 45], 'population': 358},
#    'LightVibrant': {'rgb': [196, 156, 116], 'population': 3},
#    'Muted': {'rgb': [162, 118, 97], 'population': 373},
#    'DarkMuted': {'rgb': [77, 49, 45], 'population': 305},
#    'LightMuted': {'rgb': [183, 166, 153], 'population': 378}},
#   'publishedBylines': [{'id': 1346842,
#     'name': 'Lynn Cherny',
#     'handle': 'arnicas',
#     'previous_name': None,
#     'photo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/ace812d6-e878-4ba0-af77-efeacd499379_450x512.jpeg',
#     'bio': 'AI for creativity & story, games; science fiction, TV, esoterica & weirdness. Twice-a-month newsletter on Things I Think Are Awesome: https://t.co/lgcNFxxTqj',
#     'profile_set_up_at': '2021-12-23T10:37:52.777Z',
#     'publicationUsers': [{'id': 559170,
#       'user_id': 1346842,
#       'publication_id': 626449,
#       'role': 'admin',
#       'public': True,
#       'is_primary': False,
#       'publication': {'id': 626449,
#        'name': 'Things I Think Are Awesome',
#        'subdomain': 'arnicas',
#        'custom_domain': None,
#        'custom_domain_optional': False,
#        'hero_text': 'Twice a month recs on creative AI, games and narrative tools, fun NLP and data science, generative art and text, SF/fantasy books & tv, poetry, oddities & folklore.',
#        'logo_url': 'https://bucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com/public/images/2646b087-18d7-4a3f-aced-d4f19b93406b_1024x1024.png',
#        'author_id': 1346842,
#        'theme_var_background_pop': '#B599F1',
#        'created_at': '2021-12-21T14:42:52.852Z',
#        'rss_website_url': None,
#        'email_from_name': 'Things I Think Are Awesome',
#        'copyright': 'Lynn Cherny',
#        'founding_plan_name': 'Founding Member',
#        'community_enabled': True,
#        'invite_only': False,
#        'payments_state': 'enabled',
#        'language': None,
#        'explicit': False,
#        'is_personal_mode': False}}],
#     'twitter_screen_name': 'arnicas',
#     'is_guest': False,
#     'bestseller_tier': 100}],
#   'reaction': None,
#   'reaction_count': 3,
#   'comment_count': 0,
#   'child_comment_count': 0,
#   'audio_items': [{'post_id': 142168745,
#     'voice_id': 'en-US-JennyNeural',
#     'audio_url': None,
#     'type': 'tts',
#     'status': 'paywalled'}],
#   'is_geoblocked': False,
#   'hidden': True,
#   'hasCashtag': False}]

# %% [markdown]
# ##### Get post contents (HTML only) from one newsletter post:
#
# [How a single engineer brought down Twitter on Monday](https://platformer.substack.com/p/how-a-single-engineer-brought-down)
# by Casey Newton and Zoë Schiffer.
# Mar 06, 2023

# %%
# newsletter.get_post_contents("platformer", "how-a-single-engineer-brought-down", html_only=True)

display(HTML(newsletter.get_post_contents("platformer", "how-a-single-engineer-brought-down", html_only=True)))
# Out:
# <div class="captioned-image-container"><figure><a class="image-link image2 is-viewable-img" target="_blank" href="https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fc9161e10-68a6-47b4-85d7-359c74e40b3b_1024x1024.png" data-component-name="Image2ToDOM"><div class="image2-inset"><picture><source type="image/webp" srcset="https://substackcdn.com/image/fetch/w_424,c_limit,f_webp,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fc9161e10-68a6-47b4-85d7-359c74e40b3b_1024x1024.png 424w, https://substackcdn.com/image/fetch/w_848,c_limit,f_webp,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fc9161e10-68a6-47b4-85d7-359c74e40b3b_1024x1024.png 848w, https://substackcdn.com/image/fetch/w_1272,c_limit,f_webp,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fc9161e10-68a6-47b4-85d7-359c74e40b3b_1024x1024.png 1272w, https://substackcdn.com/image/fetch/w_1456,c_limit,f_webp,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fc9161e10-68a6-47b4-85d7-359c74e40b3b_1024x1024.png 1456w" sizes="100vw"><img src="https://substackcdn.com/image/fetch/w_1456,c_limit,f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fc9161e10-68a6-47b4-85d7-359c74e40b3b_1024x1024.png" width="1024" height="1024" data-attrs="{&quot;src&quot;:&quot;https://substack-post-media.s3.amazonaws.com/public/images/c9161e10-68a6-47b4-85d7-359c74e40b3b_1024x1024.png&quot;,&quot;srcNoWatermark&quot;:null,&quot;fullscreen&quot;:null,&quot;imageSize&quot;:null,&quot;height&quot;:1024,&quot;width&quot;:1024,&quot;resizeWidth&quot;:null,&quot;bytes&quot;:1608761,&quot;alt&quot;:&quot;“a nerdy scientist sitting on top of a flying blue bird, digital art” / DALL-E&quot;,&quot;title&quot;:null,&quot;type&quot;:&quot;image/png&quot;,&quot;href&quot;:null,&quot;belowTheFold&quot;:false,&quot;topImage&quot;:true,&quot;internalRedirect&quot;:null,&quot;isProcessing&quot;:false}" class="sizing-normal" alt="“a nerdy scientist sitting on top of a flying blue bird, digital art” / DALL-E" title="“a nerdy scientist sitting on top of a flying blue bird, digital art” / DALL-E" srcset="https://substackcdn.com/image/fetch/w_424,c_limit,f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fc9161e10-68a6-47b4-85d7-359c74e40b3b_1024x1024.png 424w, https://substackcdn.com/image/fetch/w_848,c_limit,f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fc9161e10-68a6-47b4-85d7-359c74e40b3b_1024x1024.png 848w, https://substackcdn.com/image/fetch/w_1272,c_limit,f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fc9161e10-68a6-47b4-85d7-359c74e40b3b_1024x1024.png 1272w, https://substackcdn.com/image/fetch/w_1456,c_limit,f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fsubstack-post-media.s3.amazonaws.com%2Fpublic%2Fimages%2Fc9161e10-68a6-47b4-85d7-359c74e40b3b_1024x1024.png 1456w" sizes="100vw" fetchpriority="high"></picture><div class="image-link-expand"><div class="pencraft pc-display-flex pc-gap-8 pc-reset"><div class="pencraft pc-reset icon-container restack-image"><svg role="img" width="24" height="24" viewBox="0 0 24 24" fill="none" stroke-width="1.8" stroke="#000" xmlns="http://www.w3.org/2000/svg"><g><title></title><path d="M21 3V8M21 8H16M21 8L18 5.29962C16.7056 4.14183 15.1038 3.38328 13.3879 3.11547C11.6719 2.84766 9.9152 3.08203 8.32951 3.79031C6.74382 4.49858 5.39691 5.65051 4.45125 7.10715C3.5056 8.5638 3.00158 10.2629 3 11.9996M3 21V16M3 16H8M3 16L6 18.7C7.29445 19.8578 8.89623 20.6163 10.6121 20.8841C12.3281 21.152 14.0848 20.9176 15.6705 20.2093C17.2562 19.501  ...
